# %%
## This cell contains the essential imports you will need – DO NOT CHANGE THE CONTENTS! ##
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision import datasets
import matplotlib.pyplot as plt
import numpy as np
import time
import math

# %%
# Define transforms
train_transforms = transforms.Compose([
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    torch.fft.fft2,
    torch.fft.fftshift
])

valid_transforms = transforms.Compose([
    transforms.ToTensor(),
    torch.fft.fft2,
    torch.fft.fftshift
])

test_transforms = transforms.Compose([
    transforms.ToTensor(),
    torch.fft.fft2,
    torch.fft.fftshift
])


# Create training set (with no transformations)
raw_data = datasets.MNIST(root="data", train=True, download=True, transform=None)

# Split the training data into pure training data and validation data (80/20 split)
train_size = int(len(raw_data) * 0.6) # 60% training data
valid_size = int(len(raw_data) * 0.2) # 20% validation data
test_size = len(raw_data)-(train_size+valid_size)

training_data, validation_data, testing_data = torch.utils.data.random_split(raw_data, [train_size, valid_size, test_size])

# Apply the respective transformations to each dataset
training_data.dataset.transform = train_transforms
validation_data.dataset.transform = valid_transforms
testing_data.dataset.transform = test_transforms

# Create test set and define test dataloader
train_loader = DataLoader(training_data, batch_size=32, shuffle=True)
valid_loader = DataLoader(validation_data, batch_size=32)
test_loader = DataLoader(testing_data, batch_size=32)

# %%
## This cell contains a function for showing 5 images from a dataloader – DO NOT CHANGE THE CONTENTS! ##
def show5(img_loader):
    dataiter = iter(img_loader)
    
    batch = next(dataiter)
    labels = batch[1][0:5]
    images = batch[0][0:5]
    for i in range(5):
        print(int(labels[i].detach()))
        image = images[i].numpy()
        image = np.imag(image) #show the imaginary part of the image
        plt.imshow(image.T.squeeze().T)
        plt.show()
        
# Explore data
show5(train_loader)
# Out:
# 1
# 1
# 0
# 8
# 5

# %%
# F.dropout is not implemented for complex numbers yet, so here's a workaround  
class dropout_complex(nn.Module): 
    def __init__(self, p=.2): 
        super(dropout_complex, self).__init__()
        self.p = p
          
    def forward(self, x): 
        if x.is_complex():
            mask = torch.nn.functional.dropout(torch.ones_like(x.real), p=self.p)
            return x * mask
        else:
            return torch.nn.functional.dropout(x, p=self.p)

# %%
class L2_normalize(nn.Module):
    def __init__(self): 
        super(L2_normalize, self).__init__()
          
    def forward(self, z): 
        return F.normalize(z)

# %%
class Net(nn.Module):
    def __init__(self, features=[256, 128], drop_rate=0, momentum=0, learning_rate=.01, weight_decay=0, bias=False):
        """
        The Neural Network class. 
        Note: the optimizer and criterion are specified in this class itself
        ...

        Attributes
        ----------
        features : list of integers, optional, default=[256, 128]
            sets the number of features in the two hidden layers
        drop_rate : float, optional, default=.2
            sets the dropout rate
        momentum : float, optional, default=.9
            sets the momentum coefficient of the optimizer
        learning_rate : float, optional, default=.001
            sets the learning rate of the optimizer

        Methods
        -------
        train_it(epochs=10)
            trains the network, prints loss and accuracy, and returns training and validation loss history as lists
            
        test_it()
            tests the network on the test set and prints loss and accuracy
        """
        
        # Initialize base class
        super().__init__()
        
        #Define parameters
        self.bias = bias
        self.features = features
        self.activation = L2_normalize()
        
        self.drop1 = dropout_complex(p=drop_rate)
        self.z1 = nn.Linear(28*28, features[0], bias=bias, dtype=torch.cfloat)
        
        self.drop2 = dropout_complex(p=drop_rate)
        self.z2 = nn.Linear(features[0], features[1], bias=bias, dtype=torch.cfloat)
            
        self.z3 = nn.Linear(features[1], 10, bias=bias, dtype=torch.cfloat)
        
        self.output = nn.LogSoftmax(dim=1)
        
        # Define optimizer and criterion
        self.optimizer = optim.SGD(self.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay)
        self.criterion = nn.NLLLoss()
    
        
    def forward(self, x):
        x = torch.flatten(x,1)

        x = self.z1(x)
        #x = self.activation(x.abs())/x.abs()*x
        x = self.activation(x)
        x = self.drop1(x)
        
        x = self.z2(x)
        #x = self.activation(x.abs())/x.abs()*x
        x = self.activation(x)
        x = self.drop2(x)
        
        x = self.z3(x)
        x = self.output(x.abs())

        return x
    
    def train_it(self, epochs=10):
        """Trains the network

        Parameters
        ----------
        epochs : str, optional
            Number of epochs in the training run (default is 10)
        """
            
        # First choose the device to do computations on
        device = 'cpu'
        
        # Note: complex numbers are not working on mps. Fixing device to be cpu woth complex numbers
#         if torch.backends.mps.is_available():
#             device = 'mps' # Use MPS (Metal Performance Shader) on Macs
#         elif torch.cuda.is_available():
#             device = 'cuda' # Use Cuda everywhere else when GPU is available
        
        self = self.to(device)
        
        # Initialize data outputs
        train_loss_history = list()
        val_loss_history = list()
        train_accuracy_history = list()
        val_accuracy_history = list()

        for epoch in range(epochs):
            # Training 
            self.train()
            train_loss = 0.0
            train_accuracy = 0.0
            n = 0
            t0 = time.time()

            for inputs, labels in iter(train_loader):
                n += 1
                inputs, labels = inputs.to(device), labels.to(device)
                self.optimizer.zero_grad()

                outputs = self.forward(inputs)
                loss = self.criterion(outputs, labels)
                loss.backward()
                self.optimizer.step()

                train_loss = (train_loss*(n-1) + loss.item())/n

                ps = torch.exp(outputs)
                top_p, top_class = ps.topk(1, dim=1)
                equals = (top_class == labels.view(*top_class.shape))
                train_accuracy = (train_accuracy*(n-1) +100*torch.mean(equals.type(torch.FloatTensor)).item())/n

            # Validating
            self.eval()
            val_loss = 0.0
            val_accuracy = 0.0
            n = 0

            for inputs, labels in iter(valid_loader):
                n += 1
                inputs, labels = inputs.to(device), labels.to(device)
                self.optimizer.zero_grad()

                outputs = self.forward(inputs)
                loss = self.criterion(outputs, labels)

                val_loss = (val_loss*(n-1) + loss.item())/n

                ps = torch.exp(outputs)
                top_p, top_class = ps.topk(1, dim=1)
                equals = (top_class == labels.view(*top_class.shape))
                val_accuracy = (val_accuracy*(n-1) +100*torch.mean(equals.type(torch.FloatTensor)).item())/n

            train_loss_history.append(train_loss)
            train_accuracy_history.append(train_accuracy)

            val_loss_history.append(val_loss)
            val_accuracy_history.append(val_accuracy)

            print("===============================")
            print("Epoch {}/{} completed in {} seconds on {}".format(epoch+1, epochs, time.time()-t0, device))
            print("Training Loss = {}".format(train_loss))
            print("Validation Loss = {}".format(val_loss))
            print("Training Accuracy = {}%".format(train_accuracy))
            print("Validation Accuracy = {}%".format(val_accuracy))
             
 
        return train_loss_history, val_loss_history, train_accuracy_history, val_accuracy_history
    
    def test_it(self):
        """Runs a quick test on the Testing Set and prints loss and accuracy"""
        # First choose the device to do computations on
        device = 'cpu'
#         if torch.backends.mps.is_available():
#             device = 'mps' # Use MPS (Metal Performance Shader) on Macs
#         elif torch.cuda.is_available():
#             device = 'cuda' # Use Cuda everywhere else when GPU is available
        
        self = self.to(device)
        self.eval()
        test_loss = 0.0
        test_accuracy = 0.0
        n = 0

        for inputs, labels in iter(test_loader):
            n += 1
            inputs, labels = inputs.to(device), labels.to(device)
            self.optimizer.zero_grad()

            outputs = self.forward(inputs)
            loss = self.criterion(outputs, labels)

            test_loss = (test_loss*(n-1) + loss.item())/n

            ps = torch.exp(outputs)
            top_p, top_class = ps.topk(1, dim=1)
            equals = (top_class == labels.view(*top_class.shape))
            test_accuracy = (test_accuracy*(n-1) +100*torch.mean(equals.type(torch.FloatTensor)).item())/n

        print("===============================")
        print("Test Loss = {}".format(test_loss))
        print("Test Accuracy = {}%".format(test_accuracy))
        print("===============================")

# %%
net = Net(features=[200,80], drop_rate=.2, learning_rate=.01, momentum=.8, bias=True)
train_loss_history, val_loss_history, train_acc_history, val_acc_history = net.train_it(epochs=100)

plt.plot(train_loss_history, label="Training Loss")
plt.plot(val_loss_history, label="Validation Loss")
plt.legend()
plt.show()
# Out:
# ===============================
# Epoch 1/100 completed in 4.871129035949707 seconds on cpu
# Training Loss = 1.35879469537735
# Validation Loss = 0.8741406574249267
# Training Accuracy = 79.67500000000003%
# Validation Accuracy = 88.25000000000006%
# ===============================
# Epoch 2/100 completed in 4.877985954284668 seconds on cpu
# Training Loss = 0.6944891260729895
# Validation Loss = 0.5727007369995121
# Training Accuracy = 89.12777777777772%
# Validation Accuracy = 90.0083333333333%
# ===============================
# Epoch 3/100 completed in 5.014364004135132 seconds on cpu
# Training Loss = 0.504542555385166
# Validation Loss = 0.46538911962509155
# Training Accuracy = 90.60277777777786%
# Validation Accuracy = 90.57499999999996%
# ===============================
# Epoch 4/100 completed in 4.606979131698608 seconds on cpu
# Training Loss = 0.41725656359725516
# Validation Loss = 0.3982437396446865
# Training Accuracy = 91.50833333333335%
# Validation Accuracy = 91.64166666666668%
# ===============================
# Epoch 5/100 completed in 4.511026859283447 seconds on cpu
# Training Loss = 0.3645040172338487
# Validation Loss = 0.3580334889888765
# Training Accuracy = 92.26666666666672%
# Validation Accuracy = 91.79166666666667%
# ===============================
# Epoch 6/100 completed in 4.505515098571777 seconds on cpu
# Training Loss = 0.3312688859038885
# Validation Loss = 0.33216364288330025
# Training Accuracy = 92.57222222222221%
# Validation Accuracy = 92.20000000000005%
# ===============================
# Epoch 7/100 completed in 4.769209623336792 seconds on cpu
# Training Loss = 0.3077588155865671
# Validation Loss = 0.30913908636569964
# Training Accuracy = 92.81111111111117%
# Validation Accuracy = 92.45%
# ===============================
# Epoch 8/100 completed in 4.626515865325928 seconds on cpu
# Training Loss = 0.2889037612941531
# Validation Loss = 0.3009884457985563
# Training Accuracy = 93.26666666666661%
# Validation Accuracy = 92.55833333333334%
# ===============================
# Epoch 9/100 completed in 4.607577800750732 seconds on cpu
# Training Loss = 0.2745537294083176
# Validation Loss = 0.2841975948413215
# Training Accuracy = 93.44722222222222%
# Validation Accuracy = 92.88333333333335%
# ===============================
# Epoch 10/100 completed in 4.7386109828948975 seconds on cpu
# Training Loss = 0.26256363066699767
# Validation Loss = 0.27063214674592023
# Training Accuracy = 93.56388888888885%
# Validation Accuracy = 93.08333333333346%
# ===============================
# Epoch 11/100 completed in 5.435276985168457 seconds on cpu
# Training Loss = 0.25296391734811996
# Validation Loss = 0.26415105499823904
# Training Accuracy = 93.88888888888891%
# Validation Accuracy = 93.2333333333334%
# ===============================
# Epoch 12/100 completed in 5.340320110321045 seconds on cpu
# Training Loss = 0.24275194734997219
# Validation Loss = 0.2614480463961759
# Training Accuracy = 93.97222222222219%
# Validation Accuracy = 93.08333333333333%
# ===============================
# Epoch 13/100 completed in 5.399150133132935 seconds on cpu
# Training Loss = 0.23540245834655232
# Validation Loss = 0.25591261006395005
# Training Accuracy = 94.12777777777781%
# Validation Accuracy = 93.24999999999996%
# ===============================
# Epoch 14/100 completed in 5.214591979980469 seconds on cpu
# Training Loss = 0.2299093900720279
# Validation Loss = 0.2501197157800196
# Training Accuracy = 94.1972222222222%
# Validation Accuracy = 93.2583333333333%
# ===============================
# Epoch 15/100 completed in 5.463031053543091 seconds on cpu
# Training Loss = 0.22242242527339198
# Validation Loss = 0.24660199550787607
# Training Accuracy = 94.43055555555551%
# Validation Accuracy = 93.32500000000006%
# ===============================
# Epoch 16/100 completed in 5.291661977767944 seconds on cpu
# Training Loss = 0.21824885208739175
# Validation Loss = 0.24039444715778033
# Training Accuracy = 94.38611111111118%
# Validation Accuracy = 93.36666666666666%
# ===============================
# Epoch 17/100 completed in 5.352676868438721 seconds on cpu
# Training Loss = 0.2132056780225701
# Validation Loss = 0.23700572650631269
# Training Accuracy = 94.5833333333333%
# Validation Accuracy = 93.60000000000005%
# ===============================
# Epoch 18/100 completed in 5.363619089126587 seconds on cpu
# Training Loss = 0.20870299555857977
# Validation Loss = 0.23460513001680375
# Training Accuracy = 94.59166666666668%
# Validation Accuracy = 93.33333333333333%
# ===============================
# Epoch 19/100 completed in 5.395442962646484 seconds on cpu
# Training Loss = 0.20388246575329036
# Validation Loss = 0.23312622916698456
# Training Accuracy = 94.7138888888889%
# Validation Accuracy = 93.6666666666667%
# ===============================
# Epoch 20/100 completed in 5.215595006942749 seconds on cpu
# Training Loss = 0.19827375065286956
# Validation Loss = 0.22734313529729835
# Training Accuracy = 94.87500000000001%
# Validation Accuracy = 93.70833333333333%
# ===============================
# Epoch 21/100 completed in 5.411904811859131 seconds on cpu
# Training Loss = 0.19785274411903472
# Validation Loss = 0.22613131121794383
# Training Accuracy = 94.77222222222228%
# Validation Accuracy = 93.72499999999994%
# ===============================
# Epoch 22/100 completed in 5.4306230545043945 seconds on cpu
# Training Loss = 0.1930603886875841
# Validation Loss = 0.2261358494857947
# Training Accuracy = 95.02500000000002%
# Validation Accuracy = 93.64999999999998%
# ===============================
# Epoch 23/100 completed in 5.499977111816406 seconds on cpu
# Training Loss = 0.1898011587063472
# Validation Loss = 0.21947922416528065
# Training Accuracy = 95.11111111111103%
# Validation Accuracy = 94.06666666666672%
# ===============================
# Epoch 24/100 completed in 5.4016759395599365 seconds on cpu
# Training Loss = 0.18707103480895357
# Validation Loss = 0.22041769170761105
# Training Accuracy = 95.02222222222225%
# Validation Accuracy = 93.94166666666666%
# ===============================
# Epoch 25/100 completed in 5.465430021286011 seconds on cpu
# Training Loss = 0.18444280897743176
# Validation Loss = 0.22228143538037937
# Training Accuracy = 95.05277777777769%
# Validation Accuracy = 93.78333333333337%
# ===============================
# Epoch 26/100 completed in 5.138810157775879 seconds on cpu
# Training Loss = 0.18330934105647936
# Validation Loss = 0.2119798311392467
# Training Accuracy = 95.16388888888889%
# Validation Accuracy = 93.93333333333334%
# ===============================
# Epoch 27/100 completed in 5.2216408252716064 seconds on cpu
# Training Loss = 0.18103100618885626
# Validation Loss = 0.21624305958052475
# Training Accuracy = 95.15833333333333%
# Validation Accuracy = 93.9333333333333%
# ===============================
# Epoch 28/100 completed in 4.580387830734253 seconds on cpu
# Training Loss = 0.17704176159699764
# Validation Loss = 0.21577447089552879
# Training Accuracy = 95.35833333333333%
# Validation Accuracy = 93.775%
# ===============================
# Epoch 29/100 completed in 4.644112825393677 seconds on cpu
# Training Loss = 0.17512941920426164
# Validation Loss = 0.214995275263985
# Training Accuracy = 95.28333333333336%
# Validation Accuracy = 93.74166666666663%
# ===============================
# Epoch 30/100 completed in 4.572566986083984 seconds on cpu
# Training Loss = 0.1726232545508279
# Validation Loss = 0.20950685573617617
# Training Accuracy = 95.32222222222217%
# Validation Accuracy = 94.05%
# ===============================
# Epoch 31/100 completed in 4.712314128875732 seconds on cpu
# Training Loss = 0.16935974741975465
# Validation Loss = 0.2079966260045766
# Training Accuracy = 95.56666666666663%
# Validation Accuracy = 94.1333333333333%
# ===============================
# Epoch 32/100 completed in 4.653436183929443 seconds on cpu
# Training Loss = 0.16941159350673377
# Validation Loss = 0.2114455964813629
# Training Accuracy = 95.51388888888887%
# Validation Accuracy = 93.93333333333334%
# ===============================
# Epoch 33/100 completed in 4.677172422409058 seconds on cpu
# Training Loss = 0.1669218696802855
# Validation Loss = 0.21633149816095834
# Training Accuracy = 95.51666666666672%
# Validation Accuracy = 93.83333333333337%
# ===============================
# Epoch 34/100 completed in 4.60194206237793 seconds on cpu
# Training Loss = 0.16677632465627457
# Validation Loss = 0.2071528615305821
# Training Accuracy = 95.50833333333334%
# Validation Accuracy = 93.9916666666667%
# ===============================
# Epoch 35/100 completed in 4.632089138031006 seconds on cpu
# Training Loss = 0.16294935654931586
# Validation Loss = 0.21133646448453272
# Training Accuracy = 95.7138888888888%
# Validation Accuracy = 94.02500000000003%
# ===============================
# Epoch 36/100 completed in 4.634594917297363 seconds on cpu
# Training Loss = 0.1603809977504942
# Validation Loss = 0.2110755843271811
# Training Accuracy = 95.63611111111113%
# Validation Accuracy = 93.80833333333341%
# ===============================
# Epoch 37/100 completed in 4.709607124328613 seconds on cpu
# Training Loss = 0.1602117746902836
# Validation Loss = 0.2104215579926968
# Training Accuracy = 95.67222222222222%
# Validation Accuracy = 93.99166666666666%
# ===============================
# Epoch 38/100 completed in 4.990299940109253 seconds on cpu
# Training Loss = 0.1587713126622971
# Validation Loss = 0.20754227990408738
# Training Accuracy = 95.76666666666667%
# Validation Accuracy = 93.93333333333334%
# ===============================
# Epoch 39/100 completed in 4.662219047546387 seconds on cpu
# Training Loss = 0.15688351276516904
# Validation Loss = 0.20567021995286147
# Training Accuracy = 95.86388888888891%
# Validation Accuracy = 93.94166666666663%
# ===============================
# Epoch 40/100 completed in 4.5870280265808105 seconds on cpu
# Training Loss = 0.15679068127936802
# Validation Loss = 0.20054588032762224
# Training Accuracy = 95.73055555555554%
# Validation Accuracy = 93.94166666666666%
# ===============================
# Epoch 41/100 completed in 4.5738770961761475 seconds on cpu
# Training Loss = 0.15449178484413373
# Validation Loss = 0.20397785237431526
# Training Accuracy = 95.79444444444454%
# Validation Accuracy = 94.04166666666664%
# ===============================
# Epoch 42/100 completed in 4.640393972396851 seconds on cpu
# Training Loss = 0.1525292693575223
# Validation Loss = 0.2117891974101464
# Training Accuracy = 95.90277777777767%
# Validation Accuracy = 93.8%
# ===============================
# Epoch 43/100 completed in 5.001084804534912 seconds on cpu
# Training Loss = 0.15202642118434115
# Validation Loss = 0.20066129521032175
# Training Accuracy = 95.91388888888889%
# Validation Accuracy = 94.14166666666662%
# ===============================
# Epoch 44/100 completed in 5.256350040435791 seconds on cpu
# Training Loss = 0.15041729585329666
# Validation Loss = 0.19828593806425732
# Training Accuracy = 95.8972222222222%
# Validation Accuracy = 94.40833333333329%
# ===============================
# Epoch 45/100 completed in 5.354928016662598 seconds on cpu
# Training Loss = 0.1513764095306394
# Validation Loss = 0.20451089688142143
# Training Accuracy = 95.85555555555563%
# Validation Accuracy = 93.95000000000005%
# ===============================
# Epoch 46/100 completed in 4.875151872634888 seconds on cpu
# Training Loss = 0.1477634251481955
# Validation Loss = 0.19952767034371705
# Training Accuracy = 96.03333333333333%
# Validation Accuracy = 94.125%
# ===============================
# Epoch 47/100 completed in 4.940074920654297 seconds on cpu
# Training Loss = 0.14684099747406143
# Validation Loss = 0.19859744733075302
# Training Accuracy = 96.01944444444445%
# Validation Accuracy = 94.14166666666671%
# ===============================
# Epoch 48/100 completed in 4.866181135177612 seconds on cpu
# Training Loss = 0.1457433355814879
# Validation Loss = 0.19862730612357457
# Training Accuracy = 96.06944444444439%
# Validation Accuracy = 94.01666666666671%
# ===============================
# Epoch 49/100 completed in 4.925885200500488 seconds on cpu
# Training Loss = 0.14388102759089724
# Validation Loss = 0.19596816479166349
# Training Accuracy = 96.04166666666673%
# Validation Accuracy = 94.18333333333334%
# ===============================
# Epoch 50/100 completed in 4.872936964035034 seconds on cpu
# Training Loss = 0.1432413711862433
# Validation Loss = 0.19705598008881017
# Training Accuracy = 96.03888888888893%
# Validation Accuracy = 94.21666666666665%
# ===============================
# Epoch 51/100 completed in 4.865051984786987 seconds on cpu
# Training Loss = 0.1432789220925833
# Validation Loss = 0.20001438025633503
# Training Accuracy = 96.02222222222221%
# Validation Accuracy = 94.20833333333326%
# ===============================
# Epoch 52/100 completed in 4.898516893386841 seconds on cpu
# Training Loss = 0.14322603476709758
# Validation Loss = 0.1980149840414524
# Training Accuracy = 96.04166666666663%
# Validation Accuracy = 94.28333333333333%
# ===============================
# Epoch 53/100 completed in 4.968077898025513 seconds on cpu
# Training Loss = 0.14066718554993476
# Validation Loss = 0.19749838133652997
# Training Accuracy = 96.08611111111108%
# Validation Accuracy = 94.33333333333336%
# ===============================
# Epoch 54/100 completed in 4.916543960571289 seconds on cpu
# Training Loss = 0.1404553545266391
# Validation Loss = 0.19388682759304848
# Training Accuracy = 96.08888888888896%
# Validation Accuracy = 94.24166666666669%
# ===============================
# Epoch 55/100 completed in 4.902947902679443 seconds on cpu
# Training Loss = 0.13876071081062183
# Validation Loss = 0.19364315263181925
# Training Accuracy = 96.1916666666667%
# Validation Accuracy = 94.38333333333341%
# ===============================
# Epoch 56/100 completed in 4.918191909790039 seconds on cpu
# Training Loss = 0.13749394459691305
# Validation Loss = 0.19809422818819677
# Training Accuracy = 96.22777777777777%
# Validation Accuracy = 94.38333333333334%
# ===============================
# Epoch 57/100 completed in 4.878556966781616 seconds on cpu
# Training Loss = 0.13579989054799094
# Validation Loss = 0.19592014959206183
# Training Accuracy = 96.2472222222222%
# Validation Accuracy = 94.19166666666666%
# ===============================
# Epoch 58/100 completed in 4.82037615776062 seconds on cpu
# Training Loss = 0.13741611848854368
# Validation Loss = 0.19926465594768525
# Training Accuracy = 96.18055555555561%
# Validation Accuracy = 94.2416666666667%
# ===============================
# Epoch 59/100 completed in 4.583757162094116 seconds on cpu
# Training Loss = 0.13658459284239358
# Validation Loss = 0.20114321222901338
# Training Accuracy = 96.24444444444437%
# Validation Accuracy = 94.12499999999996%
# ===============================
# Epoch 60/100 completed in 4.599655866622925 seconds on cpu
# Training Loss = 0.13354724681460187
# Validation Loss = 0.20532658321907124
# Training Accuracy = 96.23055555555555%
# Validation Accuracy = 93.79999999999995%
# ===============================
# Epoch 61/100 completed in 4.631048917770386 seconds on cpu
# Training Loss = 0.13400407234744915
# Validation Loss = 0.19160126185417173
# Training Accuracy = 96.37499999999999%
# Validation Accuracy = 94.25000000000004%
# ===============================
# Epoch 62/100 completed in 5.376651763916016 seconds on cpu
# Training Loss = 0.13245440242439493
# Validation Loss = 0.20092758606374259
# Training Accuracy = 96.33333333333324%
# Validation Accuracy = 93.89166666666668%
# ===============================
# Epoch 63/100 completed in 5.516321182250977 seconds on cpu
# Training Loss = 0.13294968133171398
# Validation Loss = 0.20078801815211772
# Training Accuracy = 96.33333333333339%
# Validation Accuracy = 94.05%
# ===============================
# Epoch 64/100 completed in 5.32696795463562 seconds on cpu
# Training Loss = 0.13191321063041694
# Validation Loss = 0.1934165485054255
# Training Accuracy = 96.46666666666658%
# Validation Accuracy = 94.24166666666655%
# ===============================
# Epoch 65/100 completed in 5.399832248687744 seconds on cpu
# Training Loss = 0.12992060686233955
# Validation Loss = 0.19966713203738126
# Training Accuracy = 96.38055555555557%
# Validation Accuracy = 94.10833333333335%
# ===============================
# Epoch 66/100 completed in 5.3432090282440186 seconds on cpu
# Training Loss = 0.12930102334088742
# Validation Loss = 0.19210096845527497
# Training Accuracy = 96.39722222222225%
# Validation Accuracy = 94.33333333333333%
# ===============================
# Epoch 67/100 completed in 5.349379062652588 seconds on cpu
# Training Loss = 0.13079087189005484
# Validation Loss = 0.19642409953226642
# Training Accuracy = 96.33888888888892%
# Validation Accuracy = 94.19999999999995%
# ===============================
# Epoch 68/100 completed in 5.3122718334198 seconds on cpu
# Training Loss = 0.1283528979801467
# Validation Loss = 0.19898518700897685
# Training Accuracy = 96.36666666666673%
# Validation Accuracy = 94.1333333333333%
# ===============================
# Epoch 69/100 completed in 5.1080310344696045 seconds on cpu
# Training Loss = 0.12921321051650558
# Validation Loss = 0.19544993759940069
# Training Accuracy = 96.36388888888885%
# Validation Accuracy = 94.22500000000004%
# ===============================
# Epoch 70/100 completed in 5.3606250286102295 seconds on cpu
# Training Loss = 0.126796793916987
# Validation Loss = 0.1977908663029472
# Training Accuracy = 96.46388888888877%
# Validation Accuracy = 94.00833333333334%
# ===============================
# Epoch 71/100 completed in 5.32965612411499 seconds on cpu
# Training Loss = 0.12829247486094636
# Validation Loss = 0.1939369276364645
# Training Accuracy = 96.44444444444441%
# Validation Accuracy = 94.31666666666666%
# ===============================
# Epoch 72/100 completed in 5.29650616645813 seconds on cpu
# Training Loss = 0.12660164747304356
# Validation Loss = 0.1963454470684131
# Training Accuracy = 96.46944444444448%
# Validation Accuracy = 94.07500000000007%
# ===============================
# Epoch 73/100 completed in 5.326476097106934 seconds on cpu
# Training Loss = 0.12495327865084005
# Validation Loss = 0.19388447314004112
# Training Accuracy = 96.59166666666673%
# Validation Accuracy = 94.28333333333333%
# ===============================
# Epoch 74/100 completed in 5.289324045181274 seconds on cpu
# Training Loss = 0.12527487640827883
# Validation Loss = 0.19147146933525808
# Training Accuracy = 96.4055555555556%
# Validation Accuracy = 94.39166666666665%
# ===============================
# Epoch 75/100 completed in 5.354253053665161 seconds on cpu
# Training Loss = 0.1254436202579074
# Validation Loss = 0.18976675016433
# Training Accuracy = 96.46388888888896%
# Validation Accuracy = 94.48333333333338%
# ===============================
# Epoch 76/100 completed in 5.2373411655426025 seconds on cpu
# Training Loss = 0.12427323981208933
# Validation Loss = 0.19430246624350547
# Training Accuracy = 96.60833333333339%
# Validation Accuracy = 94.15833333333337%
# ===============================
# Epoch 77/100 completed in 4.691030979156494 seconds on cpu
# Training Loss = 0.12352481353034576
# Validation Loss = 0.19300620534270993
# Training Accuracy = 96.55277777777776%
# Validation Accuracy = 94.47499999999997%
# ===============================
# Epoch 78/100 completed in 4.584543943405151 seconds on cpu
# Training Loss = 0.12329169429341952
# Validation Loss = 0.18940542834997176
# Training Accuracy = 96.58333333333327%
# Validation Accuracy = 94.43333333333334%
# ===============================
# Epoch 79/100 completed in 4.586712837219238 seconds on cpu
# Training Loss = 0.1224509663167927
# Validation Loss = 0.194919560059905
# Training Accuracy = 96.61944444444445%
# Validation Accuracy = 94.20833333333341%
# ===============================
# Epoch 80/100 completed in 4.564964056015015 seconds on cpu
# Training Loss = 0.12056470216810704
# Validation Loss = 0.195105000582834
# Training Accuracy = 96.68055555555556%
# Validation Accuracy = 94.12499999999996%
# ===============================
# Epoch 81/100 completed in 4.544008016586304 seconds on cpu
# Training Loss = 0.12104391874455743
# Validation Loss = 0.20896595137069626
# Training Accuracy = 96.68055555555554%
# Validation Accuracy = 93.84166666666667%
# ===============================
# Epoch 82/100 completed in 4.608310699462891 seconds on cpu
# Training Loss = 0.11963015834159318
# Validation Loss = 0.2015082663868864
# Training Accuracy = 96.66944444444444%
# Validation Accuracy = 94.03333333333333%
# ===============================
# Epoch 83/100 completed in 4.60125994682312 seconds on cpu
# Training Loss = 0.11947198049641318
# Validation Loss = 0.19594277657320103
# Training Accuracy = 96.56111111111113%
# Validation Accuracy = 94.19166666666663%
# ===============================
# Epoch 84/100 completed in 4.579482078552246 seconds on cpu
# Training Loss = 0.11976419234689739
# Validation Loss = 0.19918534532934426
# Training Accuracy = 96.6638888888889%
# Validation Accuracy = 94.15000000000009%
# ===============================
# Epoch 85/100 completed in 4.590011835098267 seconds on cpu
# Training Loss = 0.11928451031446458
# Validation Loss = 0.19461883074045178
# Training Accuracy = 96.59722222222217%
# Validation Accuracy = 94.23333333333332%
# ===============================
# Epoch 86/100 completed in 4.581943035125732 seconds on cpu
# Training Loss = 0.1172859105873439
# Validation Loss = 0.19395757348587128
# Training Accuracy = 96.73611111111116%
# Validation Accuracy = 94.29999999999995%
# ===============================
# Epoch 87/100 completed in 4.5815489292144775 seconds on cpu
# Training Loss = 0.1172316325240665
# Validation Loss = 0.19195626021921627
# Training Accuracy = 96.82222222222222%
# Validation Accuracy = 94.35%
# ===============================
# Epoch 88/100 completed in 5.2897629737854 seconds on cpu
# Training Loss = 0.11770138078017367
# Validation Loss = 0.187432848756512
# Training Accuracy = 96.68333333333331%
# Validation Accuracy = 94.4916666666667%
# ===============================
# Epoch 89/100 completed in 5.277086973190308 seconds on cpu
# Training Loss = 0.11789237245917321
# Validation Loss = 0.194221166305244
# Training Accuracy = 96.72222222222219%
# Validation Accuracy = 94.3833333333333%
# ===============================
# Epoch 90/100 completed in 5.2003350257873535 seconds on cpu
# Training Loss = 0.11450433930175172
# Validation Loss = 0.1922194133748611
# Training Accuracy = 96.69722222222215%
# Validation Accuracy = 94.32499999999997%
# ===============================
# Epoch 91/100 completed in 5.344376802444458 seconds on cpu
# Training Loss = 0.11567299674782489
# Validation Loss = 0.1919261843214432
# Training Accuracy = 96.82777777777777%
# Validation Accuracy = 94.34166666666667%
# ===============================
# Epoch 92/100 completed in 5.357503890991211 seconds on cpu
# Training Loss = 0.11631650248666604
# Validation Loss = 0.19390201388796174
# Training Accuracy = 96.70000000000005%
# Validation Accuracy = 94.32500000000005%
# ===============================
# Epoch 93/100 completed in 4.929320812225342 seconds on cpu
# Training Loss = 0.11533092291735936
# Validation Loss = 0.19645184392730403
# Training Accuracy = 96.79444444444448%
# Validation Accuracy = 94.15833333333339%
# ===============================
# Epoch 94/100 completed in 4.872858285903931 seconds on cpu
# Training Loss = 0.1156723468295402
# Validation Loss = 0.19548315206418426
# Training Accuracy = 96.72777777777783%
# Validation Accuracy = 94.25833333333334%
# ===============================
# Epoch 95/100 completed in 4.762377977371216 seconds on cpu
# Training Loss = 0.11361748601661789
# Validation Loss = 0.19870620724558838
# Training Accuracy = 96.81111111111113%
# Validation Accuracy = 93.95000000000005%
# ===============================
# Epoch 96/100 completed in 4.628095865249634 seconds on cpu
# Training Loss = 0.11362668838931453
# Validation Loss = 0.19215638030941296
# Training Accuracy = 96.8%
# Validation Accuracy = 94.25833333333337%
# ===============================
# Epoch 97/100 completed in 4.561259031295776 seconds on cpu
# Training Loss = 0.11353765339487133
# Validation Loss = 0.19808105857173602
# Training Accuracy = 96.7611111111111%
# Validation Accuracy = 94.1333333333334%
# ===============================
# Epoch 98/100 completed in 4.6210103034973145 seconds on cpu
# Training Loss = 0.1127287457014123
# Validation Loss = 0.1934996578569214
# Training Accuracy = 96.8083333333333%
# Validation Accuracy = 94.49166666666665%
# ===============================
# Epoch 99/100 completed in 4.6635901927948 seconds on cpu
# Training Loss = 0.11189891319639153
# Validation Loss = 0.19535049704958996
# Training Accuracy = 96.77499999999993%
# Validation Accuracy = 94.29166666666667%
# ===============================
# Epoch 100/100 completed in 4.571896076202393 seconds on cpu
# Training Loss = 0.11112378260244925
# Validation Loss = 0.19324762083093325
# Training Accuracy = 96.88888888888886%
# Validation Accuracy = 94.20000000000005%

# %%
net.test_it()
# Out:
# ===============================
# Test Loss = 0.1942470683380962
# Test Accuracy = 94.11666666666663%
# ===============================
